# %%
import pandas as pd
from progressbar import ProgressBar
import csv
from time import time  # To time our operations
import os
os.listdir()
print(os.listdir("Data/"))#Contents of the Data folder
# Out:
# ['cz_item_category', 'item_content_cz', 'item_content_viewed_sid.csv', 'item_cz', 'list_category', 'material_attributes_cz', 'product_views_cz', 'product_views_cz_filtered.csv']

# %%
product_views_cz = pd.read_csv("Data/product_views_cz_filtered.csv",low_memory=False,encoding="utf-8")
product_views_cz.head()
# Out:
#    user_id_anon    product_id
# 0      14723304  100011803451
# 1      14723304  100011612041
# 2      14723304  100016624290
# 3      14723304       1093107
# 4      14723304  100016287573

# %%
product_views_cz = product_views_cz.loc[product_views_cz["product_id"]!="ghostery", ["user_id_anon","product_id"]]

# %%
print(len(product_views_cz))
product_views_cz["product_id"] = pd.to_numeric(product_views_cz["product_id"]).astype('Int64') #přetypování sloupce product_id
print(product_views_cz.dtypes)
# Out:
# 31502086
# user_id_anon    int64
# product_id      Int64
# dtype: object

# %%
item_cz = pd.read_csv("Data/item_cz",usecols = ["id","sid"]) #filtrování tabulky item_cz přes produkty, na které se někdo podíval
print(item_cz.head())
print(len(item_cz))
# Out:
#            id           sid
# 0  1179082107  100022742477
# 1  1218415675       2530760
# 2  1184542732  100022850488
# 3  1179295602  100022753680
# 4  1179087501  100022749351
# 10077099

# %%
item_cz_viewed = item_cz[item_cz["sid"].isin(set(product_views_cz["product_id"]))]

# %%
print(item_cz_viewed)
# Out:
#                   id           sid
# 1         1218415675       2530760
# 17           6971559       1346423
# 61           7829808       1026107
# 90        1549538267  100033492178
# 101       1214119508  100023319232
# ...              ...           ...
# 10077035     8388216    1259300009
# 10077082  1120068001  100022270996
# 10077087     6854287  100002788131
# 10077094  1497678877  100031278416
# 10077096  1411098824  100029808946
#
# [1248482 rows x 2 columns]

# %%
item_content_cz = pd.read_csv("Data/item_content_cz", usecols=["item_id","name","name_grouping","brief_plain"],nrows=1000000)
item_content_cz.head()
# Out:
#      item_id                                               name  \
# 0  108205131  Silikonové pouzdro iSaprio - Birds - Huawei Y5...
# 1    9949671  Interiérové dveře PORTO kombinované, model 2, ...
# 2    9766441         Smashed Lemon Dámské šaty Green/Blue 18516
# 3  130824063  pánské jeansy Finsbury PM200338WD2 33/34 tmavě...
# 4  830595568       dámská mikina Logo Hoodie 1895751010 L černá
#
#                                        name_grouping  \
# 0  Villager Silikonové pouzdro iSaprio - Birds - ...
# 1  VASCO DOORS Interiérové dveře PORTO kombinovan...
# 2          Dámské šaty Green/Blue 18516 (Velikost M)
# 3      Pepe Jeans pánské jeansy Finsbury PM200338WD2
# 4      Columbia dámská mikina Logo Hoodie 1895751010
#
#                                          brief_plain
# 0  Stylový ochranný kryt na mobil je vyrobený z p...
# 1  Sklo SATINATO, 80 cm, pravé dveře, bez otvoru,...
# 2  Šaty od známé značky Smashed Lemon. Elegantní ...
# 3  V pánských jeansech Finsbury od značky Pepe Je...
# 4  Dámská mikina Columbia Logo Hoodie 1895751010 ...

# %%
item_content_viewed = item_content_cz[item_content_cz["item_id"].isin(set(item_cz_viewed["id"]))] #filtrování tabulky item_content_cz přes produkty, na které se někdo podíval
print(len(item_content_viewed))
# Out:
# 135843

# %%
t = time() #postupné filtrování tabulky item_content_cz přes produkty, na které se někdo podíval

column_names = ["id", "item_id", "name", "name_grouping", "brief_plain"]
starting_row = 1000000
number_rows = 1000000
while starting_row < 10000000:
    print("skipping rows:" + str(starting_row))
    item_content_cz = pd.read_csv("Data/item_content_cz",names = column_names, skiprows = starting_row, nrows = number_rows)
    temp = item_content_cz[item_content_cz["item_id"].isin(set(item_cz_viewed["id"]))]
#     print(len(temp))
    item_content_viewed = pd.concat([item_content_viewed,temp], ignore_index=True)
#     print(len(item_content_viewed))
#     print(item_content_viewed)
    starting_row = starting_row + number_rows
    print('Time to filter: {} mins '.format(round((time() - t) / 60, 2)))
# Out:
# skipping rows:1000000
# 139891
# 275734
#            item_id                                               name  \
# 0        130824063  pánské jeansy Finsbury PM200338WD2 33/34 tmavě...
# 1        830595568       dámská mikina Logo Hoodie 1895751010 L černá
# 2        830129415                dámské šaty 41.003.82.2525 36 modrá
# 3          7748770                   Zen Pro Wmn Taupe/Coral Red 41,5
# 4        597380208  Plastový kryt - Best Friends pro Samsung Galax...
# ...            ...                                                ...
# 275729   223205622     HEITRONIC závěsná lampa CARACAS E27 230V 27021
# 275730   939148774  Kusový koberec Eton Exklusive žlutý kruh 200x2...
# 275731  1447471499  růžové dámské vzorované tenisky s koženými det...
# 275732  1582874873                                   Malovaná písanka
# 275733  1582842237                                     Mluvíme o sexu
#
#                                             name_grouping  \
# 0           Pepe Jeans pánské jeansy Finsbury PM200338WD2
# 1           Columbia dámská mikina Logo Hoodie 1895751010
# 2              Q/S designed by dámské šaty 41.003.82.2525
# 3                      Scarpa Zen Pro WMN taupe/coral red
# 4            iSaprio Plastový kryt s motivem Best Friends
# ...                                                   ...
# 275729  HEITRONIC HEITRONIC závěsná lampa CARACAS E27 ...
# 275730      Vopi Kusový koberec Eton Exklusive žlutý kruh
# 275731  Replay růžové dámské vzorované tenisky s kožen...
# 275732                                   Malovaná písanka
# 275733                                     Mluvíme o sexu
#
#                                               brief_plain            id
# 0       V pánských jeansech Finsbury od značky Pepe Je...           NaN
# 1       Dámská mikina Columbia Logo Hoodie 1895751010 ...           NaN
# 2       Dámské šifonové šaty s vypasovanou plisovanou ...           NaN
# 3       Scarpa Zen Pro W jsou dámské boty s propracova...           NaN
# 4       Plastový kryt je určený pro telefon Samsung Ga...           NaN
# ...                                                   ...           ...
# 275729  Provozní napětí: 230 V, Patice: E27, Materiál:...  1.111369e+08
# 275730  Do zlatova laděný kruhový kusový koberec Eton ...  6.340174e+08
# 275731  Barva: růžová. Vzor: zvířecí. Materiál: pravá ...  1.034837e+09
# 275732  Publikace Malovaná písanka – učíme se s žirafo...  1.152900e+09
# 275733  Teta je těhotná. Co to znamená? Za pár měsíců ...  1.152868e+09
#
# [275734 rows x 5 columns]
# Time to filter: 0.6 mins
# skipping rows:2000000
# 139068
# 414802
#           item_id                                               name  \
# 0       130824063  pánské jeansy Finsbury PM200338WD2 33/34 tmavě...
# 1       830595568       dámská mikina Logo Hoodie 1895751010 L černá
# 2       830129415                dámské šaty 41.003.82.2525 36 modrá
# 3         7748770                   Zen Pro Wmn Taupe/Coral Red 41,5
# 4       597380208  Plastový kryt - Best Friends pro Samsung Galax...
# ...           ...                                                ...
# 414797  644061420                        Sedací vak Jeans Round blue
# 414798  627647054                                 Na Dusičnany 500ml
# 414799  975101102                             Aloe Vera Ananas 500ml
# 414800  388149238            Balónek pastelový "Srdíčko" BÍLÝ, 25 cm
# 414801  972391695        Barová židle Natania (SET 2 ks), tmavě šedá
#
#                                             name_grouping  \
# 0           Pepe Jeans pánské jeansy Finsbury PM200338WD2
# 1           Columbia dámská mikina Logo Hoodie 1895751010
# 2              Q/S designed by dámské šaty 41.003.82.2525
# 3                      Scarpa Zen Pro WMN taupe/coral red
# 4            iSaprio Plastový kryt s motivem Best Friends
# ...                                                   ...
# 414797                Beanbag Sedací vak Jeans Round blue
# 414798                          Vodnář Na Dusičnany 500ml
# 414799                        Aleo Aloe Vera Ananas 500ml
# 414800  PartyDeco Balónek pastelový "Srdíčko" BÍLÝ, 25 cm
# 414801  Design Scandinavia Barová židle Natania (SET 2...
#
#                                               brief_plain           id
# 0       V pánských jeansech Finsbury od značky Pepe Je...          NaN
# 1       Dámská mikina Columbia Logo Hoodie 1895751010 ...          NaN
# 2       Dámské šifonové šaty s vypasovanou plisovanou ...          NaN
# 3       Scarpa Zen Pro W jsou dámské boty s propracova...          NaN
# 4       Plastový kryt je určený pro telefon Samsung Ga...          NaN
# ...                                                   ...          ...
# 414797                      Sedací vak Jeans Round blue\n  393235751.0
# 414798  Vodnář Na Dusičnany 500ml je přípravek ke sníž...  376008639.0
# 414799   Aloe vera nápoj s příchutí exotického ananasu.\n  667556879.0
# 414800  Pastelový balónek ve tvaru srdce lze nafouknou...  218566005.0
# 414801  Barová židle Natania má pevnou konstrukci z ma...  660418328.0
#
# [414802 rows x 5 columns]
# Time to filter: 0.99 mins
# skipping rows:3000000
# 139373
# 554175
#            item_id                                               name  \
# 0        130824063  pánské jeansy Finsbury PM200338WD2 33/34 tmavě...
# 1        830595568       dámská mikina Logo Hoodie 1895751010 L černá
# 2        830129415                dámské šaty 41.003.82.2525 36 modrá
# 3          7748770                   Zen Pro Wmn Taupe/Coral Red 41,5
# 4        597380208  Plastový kryt - Best Friends pro Samsung Galax...
# ...            ...                                                ...
# 554170  1049972369             Bamboo Cup Sybile Daisy blue M– 400 ml
# 554171   630999376               Miloš Kratochvíl: Rybáři a hastrmani
# 554172    68152111  Pánský kožený opasek 507-60 Černý (Délka pásku...
# 554173     7208102  Zlatý přívěsek srdce s krystaly 249 001 00494 ...
# 554174  1094275004  Silikonové pouzdro - Ocean pro Samsung Galaxy A51
#
#                                             name_grouping  \
# 0           Pepe Jeans pánské jeansy Finsbury PM200338WD2
# 1           Columbia dámská mikina Logo Hoodie 1895751010
# 2              Q/S designed by dámské šaty 41.003.82.2525
# 3                      Scarpa Zen Pro WMN taupe/coral red
# 4            iSaprio Plastový kryt s motivem Best Friends
# ...                                                   ...
# 554170             Bamboo Cup Sybile Daisy blue M– 400 ml
# 554171               Miloš Kratochvíl: Rybáři a hastrmani
# 554172      Penny Belts Pánský kožený opasek 507-60 Černý
# 554173  Brilio Zlatý přívěsek srdce s krystaly 249 001...
# 554174  iSaprio Silikonové pouzdro - Ocean pro Samsung...
#
#                                               brief_plain           id
# 0       V pánských jeansech Finsbury od značky Pepe Je...          NaN
# 1       Dámská mikina Columbia Logo Hoodie 1895751010 ...          NaN
# 2       Dámské šifonové šaty s vypasovanou plisovanou ...          NaN
# 3       Scarpa Zen Pro W jsou dámské boty s propracova...          NaN
# 4       Plastový kryt je určený pro telefon Samsung Ga...          NaN
# ...                                                   ...          ...
# 554170  Kelímek na teplé i studené nápoje pro opakovat...  753645914.0
# 554171  Myslíte si, že o hastrmanech víte všechno? Kde...  380245761.0
# 554172  Pánský opasek značky Penny Belts. Výrazná spon...   26280306.0
# 554173  Zlatý přívěsek srdce s krystaly 249 001 00494 ...     869014.0
# 554174  Silikonové pouzdro je určeno pro mobilní telef...  752900473.0
#
# [554175 rows x 5 columns]
# Time to filter: 1.62 mins
# skipping rows:4000000
# 137788
# 691963
#            item_id                                               name  \
# 0        130824063  pánské jeansy Finsbury PM200338WD2 33/34 tmavě...
# 1        830595568       dámská mikina Logo Hoodie 1895751010 L černá
# 2        830129415                dámské šaty 41.003.82.2525 36 modrá
# 3          7748770                   Zen Pro Wmn Taupe/Coral Red 41,5
# 4        597380208  Plastový kryt - Best Friends pro Samsung Galax...
# ...            ...                                                ...
# 691958     9718377                                    Kroužek - Notos
# 691959   996249937                      povlečení KLASIK DESIGN azték
# 691960  1145111464             LineaVZ nerezový držák na lahve GRILLY
# 691961   885779417  Chlapecké tričko s potiskem autobus Cigit Kids...
# 691962  1583814255                    Transparentní PVA lepidlo 500 g
#
#                                             name_grouping  \
# 0           Pepe Jeans pánské jeansy Finsbury PM200338WD2
# 1           Columbia dámská mikina Logo Hoodie 1895751010
# 2              Q/S designed by dámské šaty 41.003.82.2525
# 3                      Scarpa Zen Pro WMN taupe/coral red
# 4            iSaprio Plastový kryt s motivem Best Friends
# ...                                                   ...
# 691958                          Velvet SM Kroužek - Notos
# 691959            SCANquilt povlečení KLASIK DESIGN azték
# 691960  Linea VZ S.r.l. LineaVZ nerezový držák na lahv...
# 691961  Cigit Kids Chlapecké tričko s potiskem autobus...
# 691962          CLEOPATRE Transparentní PVA lepidlo 500 g
#
#                                               brief_plain            id
# 0       V pánských jeansech Finsbury od značky Pepe Je...           NaN
# 1       Dámská mikina Columbia Logo Hoodie 1895751010 ...           NaN
# 2       Dámské šifonové šaty s vypasovanou plisovanou ...           NaN
# 3       Scarpa Zen Pro W jsou dámské boty s propracova...           NaN
# 4       Plastový kryt je určený pro telefon Samsung Ga...           NaN
# ...                                                   ...           ...
# 691958  Kovový kroužek ve vysoké kvalitě se zaoblenými...  4.188931e+06
# 691959  Originální povlečení KLASIK DESIGN na kvalitní...  6.765190e+08
# 691960  LineaVZ nerezový držák na lahve GRILLY. Držák ...  7.923138e+08
# 691961  Chlapecké tričko s krátkým rukávem s potiskem ...  5.930300e+08
# 691962  Transparentní PVA lepidlo 500 g. Ideální trans...  1.153717e+09
#
# [691963 rows x 5 columns]
# Time to filter: 2.44 mins
# skipping rows:5000000
# 139444
# 831407
#            item_id                                               name  \
# 0        130824063  pánské jeansy Finsbury PM200338WD2 33/34 tmavě...
# 1        830595568       dámská mikina Logo Hoodie 1895751010 L černá
# 2        830129415                dámské šaty 41.003.82.2525 36 modrá
# 3          7748770                   Zen Pro Wmn Taupe/Coral Red 41,5
# 4        597380208  Plastový kryt - Best Friends pro Samsung Galax...
# ...            ...                                                ...
# 831402  1399588385                      stěrka 20cm dlaždice FLEXIPAD
# 831403   278444008                              Auto míchačka baterie
# 831404     9806489  Speciální profesionální štětec na make-up a pu...
# 831405   378813466           Vonná svíčka váza Lemongrass & Lily 85 g
# 831406   159123456  Osvěžující čisticí gel pro všechny typy pleti ...
#
#                                             name_grouping  \
# 0           Pepe Jeans pánské jeansy Finsbury PM200338WD2
# 1           Columbia dámská mikina Logo Hoodie 1895751010
# 2              Q/S designed by dámské šaty 41.003.82.2525
# 3                      Scarpa Zen Pro WMN taupe/coral red
# 4            iSaprio Plastový kryt s motivem Best Friends
# ...                                                   ...
# 831402                      stěrka 20cm dlaždice FLEXIPAD
# 831403                        Lamps Auto míchačka baterie
# 831404  Artdeco Speciální profesionální štětec na make...
# 831405  Woodwick Vonná svíčka váza Lemongrass & Lily 85 g
# 831406  Kilig Osvěžující čisticí gel pro všechny typy ...
#
#                                               brief_plain           id
# 0       V pánských jeansech Finsbury od značky Pepe Je...          NaN
# 1       Dámská mikina Columbia Logo Hoodie 1895751010 ...          NaN
# 2       Dámské šifonové šaty s vypasovanou plisovanou ...          NaN
# 3       Scarpa Zen Pro W jsou dámské boty s propracova...          NaN
# 4       Plastový kryt je určený pro telefon Samsung Ga...          NaN
# ...                                                   ...          ...
# 831402    Název produktu: stěrka 20cm dlaždice FLEXIPAD\n  993006816.0
# 831403  Auto míchačka nesmí chybět na žádné stavbě. A ...  144295204.0
# 831404  Profesionální štětec je ideální k aplikaci suc...    4331567.0
# 831405  Svíčka s vůní citronové trávy zjemněná něžnými...  211795970.0
# 831406  Osvěžující čisticí gel pro všechny typy pleti ...   69410116.0
#
# [831407 rows x 5 columns]
# Time to filter: 4.32 mins
# skipping rows:6000000
# 138487
# 969894
#            item_id                                               name  \
# 0        130824063  pánské jeansy Finsbury PM200338WD2 33/34 tmavě...
# 1        830595568       dámská mikina Logo Hoodie 1895751010 L černá
# 2        830129415                dámské šaty 41.003.82.2525 36 modrá
# 3          7748770                   Zen Pro Wmn Taupe/Coral Red 41,5
# 4        597380208  Plastový kryt - Best Friends pro Samsung Galax...
# ...            ...                                                ...
# 969889    12854861      Escaper Mesh Jr Paradise Pink Pearl Para 38,5
# 969890  1273074997                                  SMART - AntiVirus
# 969891   793488391                 BIG Power Worker Mini Monstertruck
# 969892  1305122898  Vzorovaný čtvercový taburet / podnožka, 80 x 8...
# 969893     9871104                          Charm X BOA M - 32,0-37,0
#
#                                             name_grouping  \
# 0           Pepe Jeans pánské jeansy Finsbury PM200338WD2
# 1           Columbia dámská mikina Logo Hoodie 1895751010
# 2              Q/S designed by dámské šaty 41.003.82.2525
# 3                      Scarpa Zen Pro WMN taupe/coral red
# 4            iSaprio Plastový kryt s motivem Best Friends
# ...                                                   ...
# 969889                               Puma Escaper Mesh Jr
# 969890                           Mindok SMART - AntiVirus
# 969891             BIG BIG Power Worker Mini Monstertruck
# 969892  Vidaxl Vzorovaný čtvercový taburet / podnožka,...
# 969893                                     K2 Charm X BOA
#
#                                               brief_plain           id
# 0       V pánských jeansech Finsbury od značky Pepe Je...          NaN
# 1       Dámská mikina Columbia Logo Hoodie 1895751010 ...          NaN
# 2       Dámské šifonové šaty s vypasovanou plisovanou ...          NaN
# 3       Scarpa Zen Pro W jsou dámské boty s propracova...          NaN
# 4       Plastový kryt je určený pro telefon Samsung Ga...          NaN
# ...                                                   ...          ...
# 969889  Puma Escaper Mesh Jr vám poskytne nový běžecký...    7613602.0
# 969890  Zapojte své tělo i mysl a zbavte se zákeřného ...  891371237.0
# 969891  BIG Power Worker Mini Monstertruck Na hřišti m...  520949381.0
# 969892  Tato stolička s prošíváním s 9 knoflíky na hor...  916420589.0
# 969893  Dětské kolečkové brusle K2 Charm X BOA lze je ...    4437085.0
#
# [969894 rows x 5 columns]
# Time to filter: 5.15 mins
# skipping rows:7000000
# 136554
# 1106448
#            item_id                                               name  \
# 0        130824063  pánské jeansy Finsbury PM200338WD2 33/34 tmavě...
# 1        830595568       dámská mikina Logo Hoodie 1895751010 L černá
# 2        830129415                dámské šaty 41.003.82.2525 36 modrá
# 3          7748770                   Zen Pro Wmn Taupe/Coral Red 41,5
# 4        597380208  Plastový kryt - Best Friends pro Samsung Galax...
# ...            ...                                                ...
# 1106443   14971486         Mastery FSE63767P + 10 let záruka na motor
# 1106444  817863297           Jídelní židle ohýbané dřevo a umělá kůže
# 1106445  979410906      Stylové oktagonové náušnice Charakter 5548748
# 1106446  157893320                              BAGMASTER MAXVELL 9 B
# 1106447  739888621  Josef Myslín: Jak správně vybrat digitální kameru
#
#                                              name_grouping  \
# 0            Pepe Jeans pánské jeansy Finsbury PM200338WD2
# 1            Columbia dámská mikina Logo Hoodie 1895751010
# 2               Q/S designed by dámské šaty 41.003.82.2525
# 3                       Scarpa Zen Pro WMN taupe/coral red
# 4             iSaprio Plastový kryt s motivem Best Friends
# ...                                                    ...
# 1106443     AEG Mastery FSE63767P + 10 let záruka na motor
# 1106444    shumee Jídelní židle ohýbané dřevo a umělá kůže
# 1106445  DKNY Stylové oktagonové náušnice Charakter 554...
# 1106446                    Bagmaster BAGMASTER MAXVELL 9 B
# 1106447  Josef Myslín: Jak správně vybrat digitální kameru
#
#                                                brief_plain           id
# 0        V pánských jeansech Finsbury od značky Pepe Je...          NaN
# 1        Dámská mikina Columbia Logo Hoodie 1895751010 ...          NaN
# 2        Dámské šifonové šaty s vypasovanou plisovanou ...          NaN
# 3        Scarpa Zen Pro W jsou dámské boty s propracova...          NaN
# 4        Plastový kryt je určený pro telefon Samsung Ga...          NaN
# ...                                                    ...          ...
# 1106443  Plně integrovaná vestavná myčka v energetické ...    9810516.0
# 1106444  Naše židle má elegantní nestárnoucí design, kt...  540231796.0
# 1106445   Stylové oktagonové náušnice Charakter 5548748.\n  665873932.0
# 1106446  Tříkomorový, prostorný školní batoh vhodný od ...   68489769.0
# 1106447  Chystáte se koupit digitální videokameru? Neví...  479375990.0
#
# [1106448 rows x 5 columns]
# Time to filter: 6.52 mins
# skipping rows:8000000
# 138559
# 1245007
#            item_id                                               name  \
# 0        130824063  pánské jeansy Finsbury PM200338WD2 33/34 tmavě...
# 1        830595568       dámská mikina Logo Hoodie 1895751010 L černá
# 2        830129415                dámské šaty 41.003.82.2525 36 modrá
# 3          7748770                   Zen Pro Wmn Taupe/Coral Red 41,5
# 4        597380208  Plastový kryt - Best Friends pro Samsung Galax...
# ...            ...                                                ...
# 1245002  549605601  Čisticí slupovací maska (Beautifying Brighteni...
# 1245003  871983950  Sprchová souprava pro vanu 1S KLUDI ZENTA Blac...
# 1245004  609527774                                       Komoda Elite
# 1245005  848689061               Posuvný držák sprchy 600 mm (CB910A)
# 1245006  911360028                       Stůl Jackie Oak Brass 160x80
#
#                                              name_grouping  \
# 0            Pepe Jeans pánské jeansy Finsbury PM200338WD2
# 1            Columbia dámská mikina Logo Hoodie 1895751010
# 2               Q/S designed by dámské šaty 41.003.82.2525
# 3                       Scarpa Zen Pro WMN taupe/coral red
# 4             iSaprio Plastový kryt s motivem Best Friends
# ...                                                    ...
# 1245002  Dermacol Čisticí slupovací maska (Beautifying ...
# 1245003  Kludi Sprchová souprava pro vanu 1S KLUDI ZENT...
# 1245004                                  KARE Komoda Elite
# 1245005         Mereo Posuvný držák sprchy 600 mm (CB910A)
# 1245006                  KARE Stůl Jackie Oak Brass 160x80
#
#                                                brief_plain           id
# 0        V pánských jeansech Finsbury od značky Pepe Je...          NaN
# 1        Dámská mikina Columbia Logo Hoodie 1895751010 ...          NaN
# 2        Dámské šifonové šaty s vypasovanou plisovanou ...          NaN
# 3        Scarpa Zen Pro W jsou dámské boty s propracova...          NaN
# 4        Plastový kryt je určený pro telefon Samsung Ga...          NaN
# ...                                                    ...          ...
# 1245002  Trendy slupovací maska s metalickým efektem. Z...  312485924.0
# 1245003  Sprchový set – KLUDI – Zenta Black&White – 606...  582552382.0
# 1245004  Elegantní komoda Elite má rovné linie v modern...  358954477.0
# 1245005  Posuvný držák sprchy se vyznačuje moderním des...  564926408.0
# 1245006  Stůl Jackie se svou přirozeností bude slušivou...  612480269.0
#
# [1245007 rows x 5 columns]
# Time to filter: 7.5 mins
# skipping rows:9000000
# 49535
# 1294542
#             item_id                                               name  \
# 0         130824063  pánské jeansy Finsbury PM200338WD2 33/34 tmavě...
# 1         830595568       dámská mikina Logo Hoodie 1895751010 L černá
# 2         830129415                dámské šaty 41.003.82.2525 36 modrá
# 3           7748770                   Zen Pro Wmn Taupe/Coral Red 41,5
# 4         597380208  Plastový kryt - Best Friends pro Samsung Galax...
# ...             ...                                                ...
# 1294537    14849153        C&K Vocal: Dřív než něco začne (4x CD) - CD
# 1294538     6513877                                     Sestava Parana
# 1294539   414155408                  Classic Dusty Green M8W10 (41-42)
# 1294540     8881982  Cantini Barbara: Mortina - Příběh, při kterém ...
# 1294541  1009763314  LED stolní lampička 2,5W/3000K/170Lm, černá s ...
#
#                                              name_grouping  \
# 0            Pepe Jeans pánské jeansy Finsbury PM200338WD2
# 1            Columbia dámská mikina Logo Hoodie 1895751010
# 2               Q/S designed by dámské šaty 41.003.82.2525
# 3                       Scarpa Zen Pro WMN taupe/coral red
# 4             iSaprio Plastový kryt s motivem Best Friends
# ...                                                    ...
# 1294537        C&K Vocal: Dřív než něco začne (4x CD) - CD
# 1294538                             Doppler Sestava Parana
# 1294539                          Crocs Classic (10001-3TD)
# 1294540  Cantini Barbara: Mortina - Příběh, při kterém ...
# 1294541  Solight LED stolní lampička 2,5W/3000K/170Lm, ...
#
#                                                brief_plain           id
# 0        V pánských jeansech Finsbury od značky Pepe Je...          NaN
# 1        Dámská mikina Columbia Logo Hoodie 1895751010 ...          NaN
# 2        Dámské šifonové šaty s vypasovanou plisovanou ...          NaN
# 3        Scarpa Zen Pro W jsou dámské boty s propracova...          NaN
# 4        Plastový kryt je určený pro telefon Samsung Ga...          NaN
# ...                                                    ...          ...
# 1294537  Hold nepochybnému fenoménu naší hudební histor...    9660974.0
# 1294538  Sestava stvořená pro odpočinek na zahradě nebo...     168478.0
# 1294539  Klasický model Crocs Classic (10001–3TD) je ob...  234773672.0
# 1294540  Mortina je sice holčička, ale trochu jiná než ...    2876752.0
# 1294541  Praktická stolní lampička s ohebným krkem a kl...  686897619.0
#
# [1294542 rows x 5 columns]
# Time to filter: 11.23 mins

# %%
item_content_viewed = item_content_viewed[["item_id","name","name_grouping","brief_plain"]]
item_content_viewed.head()
# Out:
#      item_id                                               name  \
# 0  130824063  pánské jeansy Finsbury PM200338WD2 33/34 tmavě...
# 1  830595568       dámská mikina Logo Hoodie 1895751010 L černá
# 2  830129415                dámské šaty 41.003.82.2525 36 modrá
# 3    7748770                   Zen Pro Wmn Taupe/Coral Red 41,5
# 4  597380208  Plastový kryt - Best Friends pro Samsung Galax...
#
#                                    name_grouping  \
# 0  Pepe Jeans pánské jeansy Finsbury PM200338WD2
# 1  Columbia dámská mikina Logo Hoodie 1895751010
# 2     Q/S designed by dámské šaty 41.003.82.2525
# 3             Scarpa Zen Pro WMN taupe/coral red
# 4   iSaprio Plastový kryt s motivem Best Friends
#
#                                          brief_plain
# 0  V pánských jeansech Finsbury od značky Pepe Je...
# 1  Dámská mikina Columbia Logo Hoodie 1895751010 ...
# 2  Dámské šifonové šaty s vypasovanou plisovanou ...
# 3  Scarpa Zen Pro W jsou dámské boty s propracova...
# 4  Plastový kryt je určený pro telefon Samsung Ga...

# %%
item_cz_viewed = item_cz_viewed.rename(columns={'id': 'item_id'})
print(item_cz_viewed.head())
# Out:
#         item_id           sid
# 1    1218415675       2530760
# 17      6971559       1346423
# 61      7829808       1026107
# 90   1549538267  100033492178
# 101  1214119508  100023319232

# %%
item_content_v_id = item_content_viewed.merge(item_cz_viewed, how='left', on='item_id') #spojení tabulek, přidání sloupce sid
print(item_content_v_id.head())
# Out:
#      item_id                                               name  \
# 0  130824063  pánské jeansy Finsbury PM200338WD2 33/34 tmavě...
# 1  830595568       dámská mikina Logo Hoodie 1895751010 L černá
# 2  830129415                dámské šaty 41.003.82.2525 36 modrá
# 3    7748770                   Zen Pro Wmn Taupe/Coral Red 41,5
# 4  597380208  Plastový kryt - Best Friends pro Samsung Galax...
#
#                                    name_grouping  \
# 0  Pepe Jeans pánské jeansy Finsbury PM200338WD2
# 1  Columbia dámská mikina Logo Hoodie 1895751010
# 2     Q/S designed by dámské šaty 41.003.82.2525
# 3             Scarpa Zen Pro WMN taupe/coral red
# 4   iSaprio Plastový kryt s motivem Best Friends
#
#                                          brief_plain           sid
# 0  V pánských jeansech Finsbury od značky Pepe Je...    1391559011
# 1  Dámská mikina Columbia Logo Hoodie 1895751010 ...    1511421004
# 2  Dámské šifonové šaty s vypasovanou plisovanou ...    1511205002
# 3  Scarpa Zen Pro W jsou dámské boty s propracova...    1018999010
# 4  Plastový kryt je určený pro telefon Samsung Ga...  100014844258

# %%
item_content_v_id = item_content_v_id[["sid","name","name_grouping","brief_plain"]]

# %%
# item_content_v_id.to_csv(path_or_buf="Data/item_content_viewed_sid.csv",index=False)

# %%
#celkem 1 294 542 řádků
names = ["sid", "name", "name_grouping","brief_plain"]
item_content_v_id = pd.read_csv("Data/item_content_viewed_sid.csv",names = names, skiprows = 1250000, nrows=50000)
print(item_content_v_id)
# Out:
#                 sid                                               name  \
# 0      100020294080                           HD2509R fén Compact Line
# 1      100020898450  Dámské tenisky White 5-5-23637-24-100 (Velikos...
# 2      100017038506  Dámské tenisky 1-1-23731-24-627 Saffron (Velik...
# 3      100016838945                      Narozeninová prskavka číslo 8
# 4      100029519706     Sáčky do vysavače ROWENTA Bully 3 in 1 - 12 ks
# ...             ...                                                ...
# 44538  100004145040        C&K Vocal: Dřív než něco začne (4x CD) - CD
# 44539       1010553                                     Sestava Parana
# 44540    1416452005                  Classic Dusty Green M8W10 (41-42)
# 44541  100003994287  Cantini Barbara: Mortina - Příběh, při kterém ...
# 44542  100020709700  LED stolní lampička 2,5W/3000K/170Lm, černá s ...
#
#                                            name_grouping  \
# 0                       Grundig HD2509R fén Compact Line
# 1         s.Oliver Dámské tenisky White 5-5-23637-24-100
# 2        Tamaris Dámské tenisky 1-1-23731-24-627 Saffron
# 3         Decor By Glassor Narozeninová prskavka číslo 8
# 4            VACS Sáčky do vysavače ROWENTA Bully 3 in 1
# ...                                                  ...
# 44538        C&K Vocal: Dřív než něco začne (4x CD) - CD
# 44539                             Doppler Sestava Parana
# 44540                          Crocs Classic (10001-3TD)
# 44541  Cantini Barbara: Mortina - Příběh, při kterém ...
# 44542  Solight LED stolní lampička 2,5W/3000K/170Lm, ...
#
#                                              brief_plain
# 0      Compact line, 1500W, 2 úrovně teploty / foukán...
# 1         Dámské tenisky. Vyrobeny z kvalitní koženky.\n
# 2          Dámské kožené tenisky. Precizní zpracování.\n
# 3      Narozeninová prskavka číslo 8. Nakombinujte si...
# 4      Sáčky do vysavače ROWENTA Bully 3 in 1. Vyrobe...
# ...                                                  ...
# 44538  Hold nepochybnému fenoménu naší hudební histor...
# 44539  Sestava stvořená pro odpočinek na zahradě nebo...
# 44540  Klasický model Crocs Classic (10001–3TD) je ob...
# 44541  Mortina je sice holčička, ale trochu jiná než ...
# 44542  Praktická stolní lampička s ohebným krkem a kl...
#
# [44543 rows x 4 columns]

# %%
item_content_v_id_backup = item_content_v_id

# %%
item_content_v_id = item_content_v_id_backup

# %%
#All characters to lowercase
#deletes characters: "&" "," "." "(" ")" "/" or two spaces
name_column = "name_grouping"
item_content_v_id.loc[:,name_column] = item_content_v_id[name_column].str.casefold().str.replace('&','').str.replace(',','').str.replace('(','').str.replace(')','').str.replace('.','').str.replace('/',' ').str.replace('  ',' ') 
# material_attributes_cz_no_duplicates.loc[:,"NAME_GROUPING"] = material_attributes_cz_no_duplicates.NAME_GROUPING.str.casefold().str.replace('&','').str.replace(',','').str.replace('(','').str.replace(')','').str.replace('.','').str.replace('/',' ').str.replace('  ',' ')

# %%
t = time()
pbar = ProgressBar()

def removeQuantityColor(setOfNames, name_column): #filtr of properties of product - quantity and color
    colorsCZ = ["červen", "čern", "bíl", "žlut", "zelen", "modr", "růžov", "hněd", "béžov", "tyrkysov", "oranžov", "šed", "celooranžov", "barv", "zlat", "střibrn", " vel "]
    colorsEN = ["red", "black", "white", "yellow", "green", "blue", "pink", "brown", "beige", "turquoise", "orange", "grey", "gold", "silver", "navy"]
    vel = "velikost"
    for j in pbar(setOfNames[name_column]): 
        i = j
        for String in ["ks", "mm", "mah", "cm", "let", "ml", "w", "gb", "mb", "oz", "l", "m", "a", "kg", "g", "lb", "t", "ghz", "hz", "tbl", "měs"]:
            for string in [" " + String, String]:
                index = i.find(string) #find first occurence of string in i
                while index != -1:
                    if (index != 0 and ord(i[index-1]) >= 48 and ord(i[index-1]) < 58 and #check if previous char is a number
                        ((index + len(string) < len(i) and i[index + len(string)] == ' ') or
                          index + len(string) == len(i))):
#                         print("REMOVE " + string)
#                         print(i)
                        i = i[:index]+i[index+len(string):] #slices found string from i
                        while index > 0 and ((ord(i[index-1]) >= 48 and ord(i[index-1]) < 58) or #deleting every number before
                                i[index-1] == "-" or #or characters: -,x,+,times or variants with spaces (before or after)
                                i[index-1] == "x" or
                                i[index-1] == '+' or
                                ord(i[index-1]) == 158 or
                                (index >1 and (i[index-2:index] == 'x ' or #one space before character of after
                                                i[index-2:index] == ' x' or
                                                i[index-2:index] == '- ' or 
                                                i[index-2:index] == ' -' or
                                                i[index-2:index] == '+ ' or 
                                                i[index-2:index] == ' +' or
                                                (i[index-1] == ' ' and ord(i[index-2]) == 158) or
                                                (i[index-2] == ' ' and ord(i[index-1]) == 158) or
                                                (index > 2 and (i[index-3:index] == ' x ' or #spaces on both sides of character
                                                                i[index-3:index] == ' - ' or
                                                                i[index-3:index] == ' + ' or 
                                                               (i[index-1] == ' ' and ord(i[index-2]) == 158 and i[index-3] == ' ')))))):
                            if index > 2 and (i[index-3:index] == ' x ' or #slicing of i - spaces on both sides of character
                                              i[index-3:index] == ' - ' or
                                              i[index-3:index] == ' + ' or
                                             (i[index-1] == ' ' and ord(i[index-2]) == 158 and i[index-3] == ' ')):
                                i = i[:index-3] + i[index:]
                                index = index-3
                            elif index > 2 and (ord(i[index-3]) >= 48 and ord(i[index-3]) < 58) and \
                                             (i[index-2:index] == 'x ' or #slicing of i - space on 1 side of character
                                              i[index-2:index] == ' x' or
                                              i[index-2:index] == '- ' or
                                              i[index-2:index] == ' -' or
                                              i[index-2:index] == '+ ' or
                                              i[index-2:index] == ' +' or
                                             (i[index-1] == ' ' and ord(i[index-2]) == 158) or 
                                             (i[index-2] == ' ' and ord(i[index-1]) == 158)):
                                i = i[:index-2] + i[index:]
                                index = index-2
                            elif index == 1 or (index > 1 and #slicing one character from i
                                              (i[index-2:index] != 'x ' and
                                               i[index-2:index] != ' x' and
                                               i[index-2:index] != '- ' and
                                               i[index-2:index] != ' -' and
                                               i[index-2:index] != '+ ' and
                                               i[index-2:index] != ' +')):
                                i = i[:index-1] + i[index:]
                                index = index-1
                            else:
                                break
                        if index > 0 and i[index-1] == ' ': #deletes space before quantity
                            i = i[:index-1]+i[index:]
                        index = i.find(string, index+1)
#                         print(i)
                    else:
                        index = i.find(string, index+1)
        for color in colorsCZ + colorsEN: #filtering colors from products
            index = i.find(color)
            while index != -1:
                if (color != "zelen") or (i[index:index+7] != "zelenin"): 
                    cz = 0
#                     print("REMOVE " + color)
#                     print(i)
                    if color in colorsCZ:
                        cz = 1
                    i = i[:index] + i[index+len(color)+cz:] #for czech terms slices +1 character after (sufix)
                    if (index >= 3) and (i[index-3:index] == " - "): 
                        i = i[:index-3]+i[index:]
                    elif (index > 0) and (i[index-1] == " " or i[index-1] == "-"):
                        i = i[:index-1]+i[index:]
                    index = i.find(color)
                else:
                    index = i.find(color, index+1)
        index = i.find(vel)
        sizes = ["i", "í", "x", "s", "l", "m"] #odstranění označení velikost ...
        while index != -1:
            i = i[:index] + i[index+len(vel):]
            while (len(i)>index) and \
                (i[index] == " " or 
                 i[index] in sizes or
                 (ord(i[index]) >= 48 and ord(i[index]) < 58)):
                i = i[:index]+i[index+1:]
            index = i.find(vel,index+1)
        if len(i)>0 and i[len(i)-1] == " ":
            i = i[:len(i)-1]
        while len(i)>0 and i[0] == " ":
            i = i[1:]
#         print(i)
        setOfNames.loc[setOfNames[name_column]==j, [name_column]] = i #rewrites product name in setOfNames
    
removeQuantityColor(item_content_v_id, name_column)

# material_attributes_cz_no_duplicates.loc[:,"NAME_GROUPING"] = material_attributes_cz_no_duplicates.NAME_GROUPING.str.casefold().str.replace('+ ','').str.replace('+','').str.replace('- ','').str.replace('-','').str.replace('  ',' ') 
# print(material_attributes_cz_no_duplicates)

print('Time to filter: {} mins '.format(round((time() - t) / 60, 2)))
# Out:
# 100% |########################################################################|
# Time to filter: 6.85 mins

# %%
# print(item_content_v_id.iloc[0])
item_content_v_id.loc[:, name_column] = item_content_v_id[name_column].str.replace('\+ ','').str.replace('\+','').str.replace('- ','').str.replace('-','').str.replace('  ',' ')

# %%
#spojední všech částí tabulky
item_content_filtered = item_content_filtered1.append(item_content_filtered2, ignore_index = True)
print(len(item_content_filtered))
item_content_filtered = item_content_filtered.append(item_content_filtered3, ignore_index = True)
print(len(item_content_filtered))
item_content_filtered = item_content_filtered.append(item_content_filtered4, ignore_index = True)
print(len(item_content_filtered))
item_content_filtered = item_content_filtered.append(item_content_filtered5, ignore_index = True)
print(len(item_content_filtered))
item_content_filtered = item_content_filtered.append(item_content_filtered6, ignore_index = True)
print(len(item_content_filtered))
item_content_filtered = item_content_filtered.append(item_content_filtered7, ignore_index = True)
print(len(item_content_filtered))
item_content_filtered = item_content_filtered.append(item_content_filtered8, ignore_index = True)
print(len(item_content_filtered))
item_content_filtered = item_content_filtered.append(item_content_filtered9, ignore_index = True)
print(len(item_content_filtered))
item_content_filtered = item_content_filtered.append(item_content_filtered10, ignore_index = True)
print(len(item_content_filtered))
# Out:
# 700000
# 950000
# 1000000
# 1050000
# 1100000
# 1150000
# 1200000
# 1250000
# 1294543

# %%
#odstranění duplikátů id
# item_content_filtered_no_duplicates = item_content_filtered.drop_duplicates(subset='sid', keep="last")
print(len(item_content_filtered_no_duplicates))
# item_content_filtered_no_duplicates.to_csv(path_or_buf="Data/item_content_filtered_no_duplicates.csv",index=False)
print(item_content_filtered_no_duplicates)
# Out:
# 1248406
#                   sid                                               name  \
# 1          1511421004       dámská mikina Logo Hoodie 1895751010 L černá
# 2          1511205002                dámské šaty 41.003.82.2525 36 modrá
# 3          1018999010                   Zen Pro Wmn Taupe/Coral Red 41,5
# 4        100014844258  Plastový kryt - Best Friends pro Samsung Galax...
# 5             1390883          Balení 2x ručník a 1x osuška GREEK - Navy
# ...               ...                                                ...
# 1294538  100004145040        C&K Vocal: Dřív než něco začne (4x CD) - CD
# 1294539       1010553                                     Sestava Parana
# 1294540    1416452005                  Classic Dusty Green M8W10 (41-42)
# 1294541  100003994287  Cantini Barbara: Mortina - Příběh, při kterém ...
# 1294542  100020709700  LED stolní lampička 2,5W/3000K/170Lm, černá s ...
#
#                                              name_grouping  \
# 1            columbia dámská mikina logo hoodie 1895751010
# 2                  q s designed by dámské šaty 41003822525
# 3                           scarpa zen pro wmn taupe coral
# 4             isaprio plastový kryt s motivem best friends
# 5         bes petrovice balení 2x ručník a 1x osuška greek
# ...                                                    ...
# 1294538             ck vocal: dřív než něco začne 4x cd cd
# 1294539                             doppler sestava parana
# 1294540                             crocs classic 100013td
# 1294541  cantini barbara: mortina příběh při kterém bud...
# 1294542   solight led stolní lampička 3000k 170lm s klipem
#
#                                                brief_plain
# 1        Dámská mikina Columbia Logo Hoodie 1895751010 ...
# 2        Dámské šifonové šaty s vypasovanou plisovanou ...
# 3        Scarpa Zen Pro W jsou dámské boty s propracova...
# 4        Plastový kryt je určený pro telefon Samsung Ga...
# 5        Sada 2 ručníků a 1 osušky GREEK z kvalitní bav...
# ...                                                    ...
# 1294538  Hold nepochybnému fenoménu naší hudební histor...
# 1294539  Sestava stvořená pro odpočinek na zahradě nebo...
# 1294540  Klasický model Crocs Classic (10001–3TD) je ob...
# 1294541  Mortina je sice holčička, ale trochu jiná než ...
# 1294542  Praktická stolní lampička s ohebným krkem a kl...
#
# [1248406 rows x 4 columns]

# %%
#groups ID of every product with the same name to list of IDs
item_content_list = item_content_filtered_no_duplicates.groupby('name_grouping')['sid'].apply(list)
print(item_content_list)
# Out:
# name_grouping
#                                                                                       [100018360531, 100018360537, 100022733666, 100...
# "28"" he cayo al sora 2016 51 zánovní"                                                                                      [917999001]
# "challenger 26"" dámské 180 "" zánovní"                                                                                     [932553001]
# "dětský tablet řada maxipes fík 7"" použité"                                                                                   [622196]
# "čtyři vraždy stačí drahoušku" edice klenoty českého filmu remasterovaná verze dvd                                       [100003591579]
#                                                                                                             ...
# “frau hölle” cappellová tanja: abeceda krasopsaní                                                                        [100003352935]
# ™ 1120 200 párů                                                                                                          [100011828427]
# ™ peltor™ bulls eye i                                                                                                    [100010460592]
# ™ peltor™ optime iii                                                                                                     [100030124335]
# ™ peltor™ x                                                                           [100010460602, 100005860602, 100010455540, 100...
# Name: sid, Length: 838348, dtype: object

# %%
#information new dataset of lists of IDs
length = item_content_filtered_no_duplicates.groupby('name_grouping').apply(len)
print(length.sort_values())
print(sum(length))
print(sum(length) - len(length))
print(sum(length == 1))
print(str((sum(length)-len(length))/sum(length)*100) + "% products is the same as other products")
# Out:
# name_grouping
# led žárovka zls509 e27 6000k                        1
# nines 31421 celia nugolet                           1
# nines 31441 celia coleccion mechanická panenka      1
# nines 31471 celio barret                            1
# nines 31481 celia barret                            1
#                                                  ...
# soliver dívčí tričko                              230
# seven dívčí tričko                                232
# seven chlapecké tričko                            258
# topo dívčí šaty                                   362
# happy girls dívčí šaty                            504
# Length: 838348, dtype: int64
# 1248406
# 410058
# 685341
# 32.84652588981469% products is the same as other products

# %%
print(item_content_list[""]) #najit id produktu ktere byly po sjednocení názvu pojmenovány prázdným řetězcem
print(len(item_content_list[""]))
# Out:
# [100018360531, 100018360537, 100022733666, 100002126251, 100017362505, 100003300853, 100018360532, 100034181664, 757331, 424431]
# 10

# %%
item_list = item_content_list.to_frame() #item_list obsahuje dataframe s produkty, ktere mají více id 
item_list = item_list.reset_index()
item_list.columns = ["name_grouping","list_id"]
print(item_list)
# Out:
#                                             name_grouping  \
# 0
# 1                  "28"" he cayo al sora 2016 51 zánovní"
# 2                 "challenger 26"" dámské 180 "" zánovní"
# 3            "dětský tablet řada maxipes fík 7"" použité"
# 4       "čtyři vraždy stačí drahoušku" edice klenoty č...
# ...                                                   ...
# 838343  “frau hölle” cappellová tanja: abeceda krasopsaní
# 838344                                    ™ 1120 200 párů
# 838345                              ™ peltor™ bulls eye i
# 838346                               ™ peltor™ optime iii
# 838347                                        ™ peltor™ x
#
#                                                   list_id
# 0       [100018360531, 100018360537, 100022733666, 100...
# 1                                             [917999001]
# 2                                             [932553001]
# 3                                                [622196]
# 4                                          [100003591579]
# ...                                                   ...
# 838343                                     [100003352935]
# 838344                                     [100011828427]
# 838345                                     [100010460592]
# 838346                                     [100030124335]
# 838347  [100010460602, 100005860602, 100010455540, 100...
#
# [838348 rows x 2 columns]

# %%
item_list_nonempty = item_list[item_list["name_grouping"] != ""] #nezařazuje produkty které mají po filtrování prázdný název do stejné skupiny
print(len(item_list_withempty))
print(len(item_list_nonempty))
# Out:
# 838348
# 838347

# %%
item_list_empty = item_list.loc[item_list["name_grouping"] == "", ["list_id"]] #přidá produkty s prázdným řetězcem všechny do své samotné kategorie
item_list_e = pd.DataFrame(columns = ["name_grouping", "list_id"])
liste = [i for i in list_id_empty.iloc[0]["list_id"]]
for i in liste:
    item_list_e = item_list_e.append({"name_grouping": '',"list_id":[i]},ignore_index = True)
print(item_list_e)
item_list_nonempty = item_list_nonempty.append(item_list_e,ignore_index = True)
print(item_list_nonempty)
# Out:
#    name_grouping         list_id
# 0                 [100018360531]
# 1                 [100018360537]
# 2                 [100022733666]
# 3                 [100002126251]
# 4                 [100017362505]
# 5                 [100003300853]
# 6                       [503180]
# 7                       [757330]
# 8                       [807721]
# 9                 [100018360532]
# 10                [100034181664]
# 11                      [757331]
# 12                      [424431]
#                                             name_grouping         list_id
# 0                  "28"" he cayo al sora 2016 51 zánovní"     [917999001]
# 1                 "challenger 26"" dámské 180 "" zánovní"     [932553001]
# 2            "dětský tablet řada maxipes fík 7"" použité"        [622196]
# 3       "čtyři vraždy stačí drahoušku" edice klenoty č...  [100003591579]
# 4       '47 brand kšilt nhl los angeles kings ´47 captain  [100025552567]
# ...                                                   ...             ...
# 838355                                                           [807721]
# 838356                                                     [100018360532]
# 838357                                                     [100034181664]
# 838358                                                           [757331]
# 838359                                                           [424431]
#
# [838360 rows x 2 columns]

# %%
print(item_list_nonempty)
item_list_nonempty.to_csv(path_or_buf="Data/item_list.csv",index=False)
# Out:
#                                             name_grouping         list_id
# 0                  "28"" he cayo al sora 2016 51 zánovní"     [917999001]
# 1                 "challenger 26"" dámské 180 "" zánovní"     [932553001]
# 2            "dětský tablet řada maxipes fík 7"" použité"        [622196]
# 3       "čtyři vraždy stačí drahoušku" edice klenoty č...  [100003591579]
# 4       '47 brand kšilt nhl los angeles kings ´47 captain  [100025552567]
# ...                                                   ...             ...
# 838355                                                           [807721]
# 838356                                                     [100018360532]
# 838357                                                     [100034181664]
# 838358                                                           [757331]
# 838359                                                           [424431]
#
# [838360 rows x 2 columns]

# %%
# product_views_backup = product_views_cz
print(product_views_backup)
# Out:
#           user_id_anon    product_id
# 0             14723304  100011803451
# 1             14723304  100011612041
# 2             14723304  100016624290
# 3             14723304       1093107
# 4             14723304  100016287573
# ...                ...           ...
# 31502082      54535501     992932006
# 31502083      54535501       1146359
# 31502084      54535501  100016023536
# 31502085      54535501        958947
# 31502086      54535501        908438
#
# [31502086 rows x 2 columns]

# %%
product_views_cz = product_views_backup

# %%
item_list = item_list_nonempty
item_list_containing_rewritable = item_list[item_list["list_id"].apply(len)>1] #vyřadí ty listy, ve kterých je pouze jedno id
print(item_list_containing_rewritable)
# Out:
#                                             name_grouping         list_id
# 0                  "28"" he cayo al sora 2016 51 zánovní"     [917999001]
# 1                 "challenger 26"" dámské 180 "" zánovní"     [932553001]
# 2            "dětský tablet řada maxipes fík 7"" použité"        [622196]
# 3       "čtyři vraždy stačí drahoušku" edice klenoty č...  [100003591579]
# 4       '47 brand kšilt nhl los angeles kings ´47 captain  [100025552567]
# ...                                                   ...             ...
# 838355                                                           [807721]
# 838356                                                     [100018360532]
# 838357                                                     [100034181664]
# 838358                                                           [757331]
# 838359                                                           [424431]
#
# [838360 rows x 2 columns]
#                                  name_grouping  \
# 33      100 faktů které musíš znát lidské tělo
# 41                           100 hradů a zámků
# 58        100 pokladů naší planety: divy světa
# 70               100 zábavných aktivit chlapci
# 71                 100 zábavných aktivit dívky
# ...                                        ...
# 838222  živá abeceda nová řada pro 1 ročník zš
# 838239                           žlučové mýdlo
# 838262    žádný compass guma stěrače grafitová
# 838263   žádný compass guma stěrače silikonová
# 838346                             ™ peltor™ x
#
#                                                   list_id
# 33                           [100002109754, 100016277306]
# 41                           [100002744329, 100016277331]
# 58                           [100022398566, 100030304574]
# 70                           [100000710493, 100016261824]
# 71                           [100005908472, 100016262048]
# ...                                                   ...
# 838222                       [100031825250, 100001739888]
# 838239                       [100031138659, 100000771445]
# 838262                       [100012090286, 100015814222]
# 838263                       [100012089900, 100012089838]
# 838346  [100010460602, 100005860602, 100010455540, 100...
#
# [153006 rows x 2 columns]

# %%
pbar2 = ProgressBar()

#funkce přepíše v množině setToRewriteIDs ty ID, které jsou shodné s nějakým jiným ID
def rewriteIDs(setToRewriteIDs, nameColumn, setListIDs, nameListColumn): #upravené pro setListIDs obsahující už množiny s více než jedním prvkem
    for i in pbar2(setListIDs[nameListColumn]):
        setToRewriteIDs.loc[(setToRewriteIDs[nameColumn].isin(i[1:])), nameColumn] = i[0]        

t2 = time()

prod_views = product_views_cz.iloc[17000000:]
print(prod_views)
rewriteIDs(prod_views, "product_id", item_list_containing_rewritable, "list_id")
print(prod_views)
print('Time to filter: {} mins '.format(round((time() - t2) / 60, 2)))
# Out:
#   0% |                                                                        |
#           user_id_anon    product_id
# 17000001      27059382    1404259001
# 17000002      27059382       2491241
# 17000003      27059382       1194284
# 17000004      27059382  100022208562
# 17000005      27059382       1491873
# ...                ...           ...
# 31502082      54535501     992932006
# 31502083      54535501       1146359
# 31502084      54535501  100016023536
# 31502085      54535501        958947
# 31502086      54535501        908438
#
# [14502086 rows x 2 columns]
# c:\users\pajav\source\repos\lecture4\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# 100% |########################################################################|
#           user_id_anon    product_id
# 17000001      27059382    1404259002
# 17000002      27059382       2491241
# 17000003      27059382       1194284
# 17000004      27059382  100022208562
# 17000005      27059382       1491873
# ...                ...           ...
# 31502082      54535501     992932002
# 31502083      54535501       1146359
# 31502084      54535501  100016023536
# 31502085      54535501        958947
# 31502086      54535501        908438
#
# [14502086 rows x 2 columns]
# Time to filter: 710.4 mins

# %%
product_viewes_unified = prod_views1 #spojení jednotlivých tabulek pro product_views
product_viewes_unified = product_viewes_unified.append(prod_views2, ignore_index = True)
product_viewes_unified = product_viewes_unified.append(prod_views3, ignore_index = True)
print(product_viewes_unified)
# Out:
#           user_id_anon    product_id
# 0             14723304  100011803451
# 1             14723304  100011612041
# 2             14723304  100016624290
# 3             14723304       1093107
# 4             14723304  100016287573
# ...                ...           ...
# 31502081      54535501     992932002
# 31502082      54535501       1146359
# 31502083      54535501  100016023536
# 31502084      54535501        958947
# 31502085      54535501        908438
#
# [31502086 rows x 2 columns]

# %%
product_viewes_unified.to_csv(path_or_buf="Data/product_views_unified.csv",index=False)
